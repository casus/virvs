# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.filters import threshold_otsu

# %%
gt = np.load("/bigdata/casus/MLID/maria/VIRVS_data/HADV/processed/train/y.npy")
i = 0
print(np.mean(gt)) 
plt.figure()
plt.imshow(gt[i])
plt.figure()
plt.imshow(gt[i] > -0.90)
thresh = threshold_otsu(gt.flatten())
print(thresh)
plt.figure()
plt.imshow(gt[i] > thresh)
# Out:
# -0.8784317680298018
# -0.62890625

# %%
i = 2
plt.figure()
plt.imshow(gt[i])
plt.figure()
plt.imshow(gt[i] > -0.90)
plt.figure()
plt.imshow(gt[i] > thresh)

# %%
gt = np.load("/bigdata/casus/MLID/maria/VIRVS_data/VACV/processed/train/y.npy")
i = 0
print(np.mean(gt)) 
plt.figure()
plt.imshow(gt[i])
plt.figure()
plt.imshow(gt[i] > -0.80)
# Out:
# -0.7990316379590755

# %%
i = 2
plt.figure()
plt.imshow(gt[i])
plt.figure()
plt.imshow(gt[i] > -0.80)

# %%
gt = np.load("/bigdata/casus/MLID/maria/VIRVS_data/HSV/processed/train/y.npy")
i = 0
print(np.mean(gt)) 
plt.figure()
plt.imshow(gt[i])
plt.figure()
plt.imshow(gt[i] > -0.80)
# Out:
# -0.9195019230416599

# %%
i = 2
plt.figure()
plt.imshow(gt[i])
plt.figure()
plt.imshow(gt[i] > -0.80)

# %%
gt = np.load("/bigdata/casus/MLID/maria/VIRVS_data/RV/processed/train/y.npy")
i = 0
print(np.mean(gt)) 
plt.figure()
plt.imshow(gt[i])
plt.figure()
plt.imshow(gt[i] > -0.80)
# Out:
# -0.9069569922140147

# %%
i = 2
print(np.mean(gt)) 
plt.figure()
plt.imshow(gt[i])
plt.figure()
plt.imshow(gt[i] > -0.80)
# Out:
# -0.9069569922140147

# %%
gt = np.load("/bigdata/casus/MLID/maria/VIRVS_data/IAV/processed/train/y.npy")
i = 0
print(np.mean(gt)) 
plt.figure()
plt.imshow(gt[i])
plt.figure()
plt.imshow(gt[i] > -0.80)
# Out:
# -0.8954311622887279

# %%
i = 2
print(np.mean(gt)) 
plt.figure()
plt.imshow(gt[i])
plt.figure()
plt.imshow(gt[i] > -0.80)
# Out:
# -0.8954311622887279
